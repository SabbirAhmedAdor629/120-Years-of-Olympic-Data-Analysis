# %%
import pandas as pd
import seaborn as sns

# %%
ds=pd.read_csv('/content/drive/MyDrive/SP PROJECT2/athlete_events.csv')

# %%
ds.head()
# Out:
#    ID                      Name  ...                             Event  Medal
# 0   1                 A Dijiang  ...       Basketball Men's Basketball    NaN
# 1   2                  A Lamusi  ...      Judo Men's Extra-Lightweight    NaN
# 2   3       Gunnar Nielsen Aaby  ...           Football Men's Football    NaN
# 3   4      Edgar Lindenau Aabye  ...       Tug-Of-War Men's Tug-Of-War   Gold
# 4   5  Christine Jacoba Aaftink  ...  Speed Skating Women's 500 metres    NaN
#
# [5 rows x 15 columns]

# %% [markdown]
# E2

# %%
sns.countplot(x='Team',data=ds,hue='NOC')

# %% [markdown]
# E3

# %%
sns.countplot(x='Event',data=ds,hue='Year')
ds['Year'].value_counts()
# Out:
# 1992    16413
# 1988    14676
# 2000    13821
# 1996    13780
# 2016    13688
# 2008    13602
# 2004    13443
# 2012    12920
# 1972    11959
# 1984    11588
# 1976    10502
# 1968    10479
# 1964     9480
# 1952     9358
# 1960     9235
# 1980     8937
# 1948     7480
# 1936     7401
# 1956     6434
# 1924     5693
# 1928     5574
# 2014     4891
# 2010     4402
# 2006     4382
# 1920     4292
# 2002     4109
# 1912     4040
# 1998     3605
# 1932     3321
# 1994     3160
# 1908     3101
# 1900     1936
# 1906     1733
# 1904     1301
# 1896      380
# Name: Year, dtype: int64

# %% [markdown]
# E4

# %%
sns.countplot(x='Year',data=ds,hue='Team')
ds['Year'].value_counts()
ds['Team'].value_counts()
# Out:
# United States    17847
# France           11988
# Great Britain    11404
# Italy            10260
# Germany           9326
#                  ...
# Potsdam              1
# Danzig               1
# Leipzig              1
# Augsburg             1
# Femur-18             1
# Name: Team, Length: 1184, dtype: int64

# %% [markdown]
# H5

# %%
sns.countplot(x='NOC',data=ds,hue='Medal')
ds['NOC'].value_counts()
# Out:
# USA    18853
# FRA    12758
# GBR    12256
# ITA    10715
# GER     9830
#        ...
# YMD        5
# SSD        3
# UNK        2
# NBO        2
# NFL        1
# Name: NOC, Length: 230, dtype: int64

# %% [markdown]
# H7

# %%
sns.countplot(x='City',data=ds,hue='Medal')

# %% [markdown]
# R9

# %%
sns.countplot(x='Event',data=ds,hue='NOC')

# %% [markdown]
# R10

# %%
sns.countplot(x='Event',data=ds,hue='City')
