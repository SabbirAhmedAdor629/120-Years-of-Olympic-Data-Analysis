# %%
import pandas as pd
import seaborn as sns

# %%
ds=pd.read_csv('/content/drive/MyDrive/SP PROJECT2/athlete_events.csv')

# %%
ds.head()
# Out:
#    ID                      Name  ...                             Event  Medal
# 0   1                 A Dijiang  ...       Basketball Men's Basketball    NaN
# 1   2                  A Lamusi  ...      Judo Men's Extra-Lightweight    NaN
# 2   3       Gunnar Nielsen Aaby  ...           Football Men's Football    NaN
# 3   4      Edgar Lindenau Aabye  ...       Tug-Of-War Men's Tug-Of-War   Gold
# 4   5  Christine Jacoba Aaftink  ...  Speed Skating Women's 500 metres    NaN
#
# [5 rows x 15 columns]

# %% [markdown]
# A12

# %%
sns.countplot(x='Sport',data=ds,hue='Sex')
ds['Sex'].value_counts()
# Out:
# M    196594
# F     74522
# Name: Sex, dtype: int64

# %% [markdown]
# A13

# %%
sns.countplot(x='Sex',data=ds,hue='Medal')

# %% [markdown]
# A14

# %%
sns.countplot(x='Medal',data=ds,hue='Age')
ds['Medal'].value_counts()
# Out:
# Gold      13372
# Bronze    13295
# Silver    13116
# Name: Medal, dtype: int64

# %% [markdown]
# T16

# %%
sns.countplot(x='Year',data=ds)

# %%
sns.countplot(x='Event',data=ds,hue='Year')

# %%
sns.countplot(x='Medal',data=ds,hue='Year')

# %% [markdown]
# T17

# %%
sns.countplot(x='NOC',data=ds)

# %%
sns.countplot(x='Sport',data=ds)
ds['Sport'].value_counts()
# Out:
# Athletics        38624
# Gymnastics       26707
# Swimming         23195
# Shooting         11448
# Cycling          10859
#                  ...
# Racquets            12
# Jeu De Paume        11
# Roque                4
# Basque Pelota        2
# Aeronautics          1
# Name: Sport, Length: 66, dtype: int64

# %%
sns.countplot(x='Sport',data=ds,hue='Team')

# %% [markdown]
# T18

# %%
sns.countplot(x='Sport',data=ds,hue='Medal')

# %%
sns.countplot(x='Sex',data=ds,hue='Medal')
ds['Sex'].value_counts()
# Out:
# M    196594
# F     74522
# Name: Sex, dtype: int64
